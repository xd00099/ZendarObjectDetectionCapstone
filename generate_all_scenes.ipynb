# %%
NUM_SCENES = 125

for i in range(NUM_SCENES + 1):
    file_path = f'data/{str(i).zfill(5)}.npz'
    # !python run.py --data {file_path}
# Out:
# Loading data for: data/00000.npz
# Loading camera frames.
# Loading data for: data/00001.npz
# Loading camera frames.
# Loading data for: data/00002.npz
# Loading camera frames.
# Loading data for: data/00003.npz
# Loading camera frames.
# Loading data for: data/00004.npz
# Loading camera frames.
# Loading data for: data/00005.npz
# Loading camera frames.
# Loading data for: data/00006.npz
# Loading camera frames.
# Loading data for: data/00007.npz
# Loading camera frames.
# Loading data for: data/00008.npz
# Loading camera frames.
# Loading data for: data/00009.npz
# Loading camera frames.
# Loading data for: data/00010.npz
# Loading camera frames.
# Loading data for: data/00011.npz
# Loading camera frames.
# Loading data for: data/00012.npz
# Loading camera frames.
# Loading data for: data/00013.npz
# Loading camera frames.
# Loading data for: data/00014.npz
# Loading camera frames.
# Loading data for: data/00015.npz
# Loading camera frames.
# Loading data for: data/00016.npz
# ...
